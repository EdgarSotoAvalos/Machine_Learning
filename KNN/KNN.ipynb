# %%
'''
PRACTICA 2
Integrantes del equipo:
-Cordova Zapata Joseph Alejandro
-Soto Avalos Edgar
'''

from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

iris = load_iris()

X = iris.data
y = iris.target
i=0
# Definir los valores de k
k_values = [1, 4, 7]

# Inicializar listas para almacenar los valores de las métricas para cada valor de k
accuracy_k1 = []
precision_k1 = []
recall_k1 = []
f1_k1 = []
accuracy_k4 = []
precision_k4 = []
recall_k4 = []
f1_k4 = []
accuracy_k7 = []
precision_k7 = []
recall_k7 = []
f1_k7 = []

# Definir el objeto StratifiedKFold con 10 pliegues
skf = StratifiedKFold(n_splits=10)

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    i=i+1
    # Iterar sobre los valores de k y entrenar un modelo para cada uno
    for k in k_values:
        # Definir el clasificador KNeighbors con el valor actual de k
        knn = KNeighborsClassifier(n_neighbors=k)

        # Entrenar el modelo con el conjunto de entrenamiento
        knn.fit(X_train, y_train)

        # Predecir las etiquetas objetivo del conjunto de prueba
        y_pred = knn.predict(X_test)

        # calcular métricas de evaluación
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        # Agregar los valores a las listas correspondientes
        if k == 1:
            accuracy_k1.append(accuracy)
            precision_k1.append(precision)
            recall_k1.append(recall)
            f1_k1.append(f1)
        elif k == 4:
            accuracy_k4.append(accuracy)
            precision_k4.append(precision)
            recall_k4.append(recall)
            f1_k4.append(f1)
        else:
            accuracy_k7.append(accuracy)
            precision_k7.append(precision)
            recall_k7.append(recall)
            f1_k7.append(f1)

        # imprimir resultados
        print("-----------Ejecucion:  ",i,"con k=",k,"-------------")
        print("Exactitud:", accuracy)
        print("Precisión:", precision)
        print("Sensibilidad:", recall)
        print("f1-score:", f1)

# Calcular los promedios para cada valor de k
accuracy_k1_mean = np.mean(accuracy_k1)
precision_k1_mean = np.mean(precision_k1)
recall_k1_mean = np.mean(recall_k1)
f1_k1_mean = np.mean(f1_k1)
accuracy_k4_mean = np.mean(accuracy_k4)
precision_k4_mean = np.mean(precision_k4)
recall_k4_mean = np.mean(recall_k4)
f1_k4_mean = np.mean(f1_k4)
accuracy_k7_mean = np.mean(accuracy_k7)
precision_k7_mean = np.mean(precision_k7)
recall_k7_mean = np.mean(recall_k7)
f1_k7_mean = np.mean(f1_k7)

print("----------------Promedios")
print("Promedios para k = 1")
print("Exactitud:", accuracy_k1_mean)
print("Precisión:", precision_k1_mean)
print("Sensibilidad:", recall_k1_mean)
print("f1-score:", f1_k1_mean)

print("Promedios para k = 4")
print("Exactitud:", accuracy_k4_mean)
print("Precisión:", precision_k4_mean)
print("Sensibilidad:", recall_k4_mean)
print("f1-score:", f1_k4_mean)

print("Promedios para k = 7")
print("Exactitud:", accuracy_k7_mean)
print("Precisión:", precision_k7_mean)
print("Sensibilidad:", recall_k7_mean)
print("f1-score:", f1_k7_mean)
# Out:
# -----------Ejecucion:   1 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   1 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   1 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   2 con k= 1 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   2 con k= 4 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   2 con k= 7 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   3 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   3 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   3 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   4 con k= 1 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   4 con k= 4 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   4 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   5 con k= 1 -------------
# Exactitud: 0.8666666666666667
# Precisión: 0.9047619047619048
# Sensibilidad: 0.8666666666666667
# f1-score: 0.861111111111111
# -----------Ejecucion:   5 con k= 4 -------------
# Exactitud: 0.8666666666666667
# Precisión: 0.9047619047619048
# Sensibilidad: 0.8666666666666667
# f1-score: 0.861111111111111
# -----------Ejecucion:   5 con k= 7 -------------
# Exactitud: 0.8666666666666667
# Precisión: 0.9047619047619048
# Sensibilidad: 0.8666666666666667
# f1-score: 0.861111111111111
# -----------Ejecucion:   6 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   6 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   6 con k= 7 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   7 con k= 1 -------------
# Exactitud: 0.8666666666666667
# Precisión: 0.8666666666666667
# Sensibilidad: 0.8666666666666667
# f1-score: 0.8666666666666668
# -----------Ejecucion:   7 con k= 4 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   7 con k= 7 -------------
# Exactitud: 0.9333333333333333
# Precisión: 0.9444444444444445
# Sensibilidad: 0.9333333333333332
# f1-score: 0.9326599326599326
# -----------Ejecucion:   8 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   8 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   8 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   9 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   9 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   9 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   10 con k= 1 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   10 con k= 4 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# -----------Ejecucion:   10 con k= 7 -------------
# Exactitud: 1.0
# Precisión: 1.0
# Sensibilidad: 1.0
# f1-score: 1.0
# ----------------Promedios
# Promedios para k = 1
# Exactitud: 0.96
# Precisión: 0.9660317460317461
# Sensibilidad: 0.96
# f1-score: 0.9593097643097643
# Promedios para k = 4
# Exactitud: 0.9666666666666666
# Precisión: 0.9738095238095239
# Sensibilidad: 0.9666666666666666
# f1-score: 0.9659090909090908
# Promedios para k = 7
# Exactitud: 0.9666666666666668
# Precisión: 0.9738095238095239
# Sensibilidad: 0.9666666666666666
# f1-score: 0.9659090909090908
